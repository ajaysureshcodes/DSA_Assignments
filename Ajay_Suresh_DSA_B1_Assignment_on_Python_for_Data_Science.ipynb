# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Reading the dataset to python environment
df = pd.read_excel('/content/iris.xls')

# %%
#displaying the columns in the data
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#Calculate the mean of each column of the dataset
df.mean()
#'Classifictaion is of object column hence the warning
# Out:
# <ipython-input-9-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#Checking for the null values present in the dataset.
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#Checking for unique elements in the iris data set
df['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#Renaming the data for better understanding based in the Iris flowers
df = df.rename(columns = {'SL':'Sepal Length', 'SW':'Sepal Width','PL':'Petal Length','PW':'Petal Width'})

# %%
df.groupby('Classification')['Sepal Length'].sum().plot(kind = 'line', figsize= (10,6), marker = 'o', color = 'purple')
plt.xlabel('Classification')
plt.xticks(rotation = 0)
plt.ylabel('Average Sepal Length')
plt.title('Iris versions vs Avg Sepal Length')
plt.show()

# %%
df.groupby('Classification')['Sepal Length'].plot.hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Sepal Length in Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# %%
df.groupby('Classification')['Petal Length'].mean().plot(kind='bar', color=['green', 'blue', 'coral'], edgecolor = 'black')
plt.title('Average Petal Length by Different Species in Iris Dataset')
plt.xlabel('Classification')
plt.ylabel('Average Petal Length')
plt.show()

# %%
# Pair plot for feature comparison based on Classification
sns.pairplot(df, hue='Classification', markers=['o', 's', 'D'])
plt.title('Pair Plot for Iris')
plt.show()

# %%
# Box plots for each Classification of Iris species
plt.figure(figsize=(12, 8))
sns.boxplot(x='Classification', y='Petal Width', data=df)
plt.title('Box Plot of Petal Width by Species')
plt.show()

# %%
# Create swarm plots for each species for Sepal Width
plt.figure(figsize=(12, 8))
sns.swarmplot(x='Classification', y='Sepal Width', data=df, color = 'orange')
plt.title('Swarm Plot of Sepal Width by Species')
plt.show()

# %%
# Correlation heatmap for all features
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Features in Iris data')
plt.show()
# Out:
# <ipython-input-23-95cf7bff74e2>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
